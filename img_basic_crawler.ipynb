# %%
! pip install PyQt6
! pip install google-generativeai
# Out:
# Requirement already satisfied: PyQt6 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (6.7.0)
# Requirement already satisfied: PyQt6-sip<14,>=13.6 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from PyQt6) (13.6.0)
# Requirement already satisfied: PyQt6-Qt6<6.8.0,>=6.7.0 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from PyQt6) (6.7.0)
# Requirement already satisfied: google-generativeai in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (0.5.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.4 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (0.6.4)
# Requirement already satisfied: google-api-core in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (2.19.0)
# Requirement already satisfied: google-api-python-client in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (2.130.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (2.29.0)
# Requirement already satisfied: protobuf in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (4.25.3)
# Requirement already satisfied: pydantic in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (2.7.1)
# Requirement already satisfied: tqdm in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (4.66.4)
# Requirement already satisfied: typing-extensions in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-generativeai) (4.12.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-ai-generativelanguage==0.6.4->google-generativeai) (1.23.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-api-core->google-generativeai) (1.63.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-api-core->google-generativeai) (2.32.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from pydantic->google-generativeai) (2.18.2)
# Requirement already satisfied: colorama in c:\users\yeon2\appdata\roaming\python\python312\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai) (1.64.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.4->google-generativeai) (1.62.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yeon2\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.2.2)

# %% [markdown]
#
#
#     # 스트리밍 응답
#     response = model.generate_content(prompt, stream=False)
#     response.resolve()  # 스트리밍 응답에서 필요
#
#     story_output.setText(response.text)
#
# def main():import sys
# from PyQt6.QtWidgets import QApplication, QWidget, QVBoxLayout, QLabel, QLineEdit, QComboBox, QPushButton, QTextEdit
# import pathlib
# import textwrap
# import PIL.Image
# import google.generativeai as genai
#
# global keyword_input
# global style_input
# global story_output
# global model
#
# def generate_story():
#     global model
#     keywords = keyword_input.text()
#     style = style_input.currentText()
#     prompt = f"다음 조건을 지켜 7문장 정도의 재미있는 이야기를 지어주세요. 포함할 키워드: {keywords}, 이야기의 문체: {style}"
#
#     # 안전성 설정
#     global model
#     app = QApplication(sys.argv)
#
#     # API 키 설정
#     GOOGLE_API_KEY = 'AIzaSyA5Lk3gdM4ONVuZyjlw_MzgI3VXC-_jj4M'
#     genai.configure(api_key=GOOGLE_API_KEY)
#
#     # 모델 선택 (텍스트 전용 또는 이미지+텍스트)
#     model = genai.GenerativeModel('gemini-1.5-flash-latest')  # 텍스트 전용
#     # model = genai.GenerativeModel('gemini-1.0-pro-vision-latest')  # 이미지+텍스트
#
#     window = QWidget()
#     window.setWindowTitle("잼얘 생성기")
#
#     layout = QVBoxLayout()
#
#     keyword_label = QLabel("키워드:")
#     layout.addWidget(keyword_label)
#
#     global keyword_input
#     keyword_input = QLineEdit()
#     layout.addWidget(keyword_input)
#
#     style_label = QLabel("문체:")
#     layout.addWidget(style_label)
#
#     global style_input
#     style_input = QComboBox()
#     style_input.addItems(["유머러스", "서정적", "모험심", "판타지", "미스터리", "공포", "로맨스", "SF", "역사"])
#     layout.addWidget(style_input)
#
#     generate_button = QPushButton("이야기 생성")
#     generate_button.clicked.connect(generate_story)
#     layout.addWidget(generate_button)
#
#     global story_output
#     story_output = QTextEdit()
#     story_output.setReadOnly(True)
#     layout.addWidget(story_output)
#
#     window.setLayout(layout)
#     window.show()
#
#     sys.exit(app.exec())
#
# if __name__ == '__main__':
#     main()
